# %%
#예제1
s = 'café'
len(s)
# Out:
# 4

# %%
#예제1-1
b = s.encode('utf8')
b
# Out:
# b'caf\xc3\xa9'

# %%
#예제1-2
len(b)
# Out:
# 5

# %%
#예제1-3
b.decode('utf8')
# Out:
# 'café'

# %%
#예제2
cafe = bytes('café', encoding='utf_8')
cafe
# Out:
# b'caf\xc3\xa9'

# %%
#예제2-1
cafe[0]
# Out:
# 99

# %%
#예제2-2
cafe[:1]
# Out:
# b'c'

# %%
#예제2-3
cafe_arr = bytearray(cafe)
cafe_arr
# Out:
# bytearray(b'caf\xc3\xa9')

# %%
#예제2-4
cafe_arr[-1:]
# Out:
# bytearray(b'\xa9')

# %%
#예제3
bytes.fromhex('31 4B CE A9')
# Out:
# b'1K\xce\xa9'

# %%
#예제4
import array
numbers = array.array('h', [-2, -1, 0, 1, 2])
numbers
# Out:
# array('h', [-2, -1, 0, 1, 2])

# %%
#예제4-1
octets = bytes(numbers)
octets
# Out:
# b'\xfe\xff\xff\xff\x00\x00\x01\x00\x02\x00'

# %%
#예제5
import struct
fmt = '<3s3sHH'
with open('./simpsons.gif', 'rb') as fp:
    img = memoryview(fp.read())
header = img[:10]
bytes(header)
# Out:
# b'GIF89a\xf3\x01k\x01'

# %%
#예제5-1
struct.unpack(fmt, header)
# Out:
# (b'GIF', b'89a', 499, 363)

# %%
#예제5-2
del header
del img

# %%
#예제6
for codec in ['latin_1', 'utf8', 'utf_16']:
    print(codec, 'El Niño'.encode(codec), sep='\t')
# Out:
# latin_1	b'El Ni\xf1o'
# utf8	b'El Ni\xc3\xb1o'
# utf_16	b'\xff\xfeE\x00l\x00 \x00N\x00i\x00\xf1\x00o\x00'

# %%
#예제6-1
for codec in ['ascii', 'latin_1', 'cp1252', 'cp437', 'utf8', 'utf_16', 'gb2312'] :
    print(codec, 'A'.encode(codec), sep='\t')
# Out:
# ascii	b'A'
# latin_1	b'A'
# cp1252	b'A'
# cp437	b'A'
# utf8	b'A'
# utf_16	b'\xff\xfeA\x00'
# gb2312	b'A'

# %%
#예제7
city = 'São Paulo'
city.encode('utf-8')
# Out:
# b'S\xc3\xa3o Paulo'

# %%
#예제7-1
city.encode('utf_16')
# Out:
# b'\xff\xfeS\x00\xe3\x00o\x00 \x00P\x00a\x00u\x00l\x00o\x00'

# %%
#예제7-2
city.encode('iso8859_1')
# Out:
# b'S\xe3o Paulo'

# %%
#예제7-3
city.encode('cp437')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-39-66d388b607f9> in <cell line: 2>()
#       1 #예제7-3
# ----> 2 city.encode('cp437')
#
# /usr/lib/python3.10/encodings/cp437.py in encode(self, input, errors)
#      10
#      11     def encode(self,input,errors='strict'):
# ---> 12         return codecs.charmap_encode(input,errors,encoding_map)
#      13
#      14     def decode(self,input,errors='strict'):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\xe3' in position 1: character maps to <undefined>

# %%
#예제7-4
city.encode('cp437', errors='ignore')
# Out:
# b'So Paulo'

# %%
#예제7-5
city.encode('cp437', errors='replace')
# Out:
# b'S?o Paulo'

# %%
#예제7-6
city.encode('cp437', errors='xmlcharrefreplace')
# Out:
# b'S&#227;o Paulo'

# %%
#예제8
octets = b'Montr\xe9al'
octets.decode('cp1252')
# Out:
# 'Montréal'

# %%
#예제8-1
octets.decode('iso8859_7')
# Out:
# 'Montrιal'

# %%
#예제8-2
octets.decode('koi8_r')
# Out:
# 'MontrИal'

# %%
#예제8-3
octets.decode('utf_8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-46-8f92427f4b13> in <cell line: 2>()
#       1 #예제8-3
# ----> 2 octets.decode('utf_8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 5: invalid continuation byte

# %%
#예제8-4
octets.decode('utf_8', errors='replace')
# Out:
# 'Montr�al'

# %%
#예제8-5
'é'.encode('utf-8')
# Out:
# b'\xc3\xa9'

# %%
#예제9
u16 = 'El Niño'.encode('utf_16')
u16
# Out:
# b'\xff\xfeE\x00l\x00 \x00N\x00i\x00\xf1\x00o\x00'

# %%
#예제9-1
list(u16)
# Out:
# [255, 254, 69, 0, 108, 0, 32, 0, 78, 0, 105, 0, 241, 0, 111, 0]

# %%
#예제9-2
u16le = 'El Niño'.encode('utf_16le')
list(u16le)
# Out:
# [69, 0, 108, 0, 32, 0, 78, 0, 105, 0, 241, 0, 111, 0]

# %%
#예제9-3
u16be = 'El Niño'.encode('utf_16be')
list(u16be)
# Out:
# [0, 69, 0, 108, 0, 32, 0, 78, 0, 105, 0, 241, 0, 111]
